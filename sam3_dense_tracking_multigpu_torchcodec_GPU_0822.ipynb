# %% [markdown]
# # SAM3 Dense Tracking (MultiGPU)

# %% [markdown]
# ## 0. Prerequisites

# %% [markdown]
# #### Conda env
#
# In case there are any environment or dependency errors on FAIR-SC, you can **directly use Ronghang's FAIR-SC conda env via**
# ```
# conda activate /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3
# ```
# which contains all dependencies we need for this notebook.

# %% [markdown]
# #### GPU setup
#
# This notebook is expected to run on an **interactive slurm node with multiple (ideally 8) GPUs**. You can do the following to get an 8-GPU slurm session on FAIR-SC
# ```
# srun --mem=480g --nodes=1 --gres=gpu:8 --account=sam3 --qos=h200_sam3_high --time=160:00:00 --cpus-per-task=80 --pty /bin/bash -l
# ```
# and launch the Jupyter notebook from there via
# ```
# conda activate /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3
# jupyter notebook --port 8888 --ip 0.0.0.0 --no-browser
# ```
#
# Then, **forward the Jupyter notebook port to your Meta laptop**:
# ```
# ssh <your-fair-sc-ssh-config> -fNL 8888:h200-241-207:8888
# ```
# where `8888` is the Jupyter notebook port and `h200-241-207` is the interactive slurm node's hostname (**replace them with your actual port and slurm node hostname**).

# %%
# !nvidia-smi
# Out:
# Sat Aug 23 00:34:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.05              Driver Version: 560.35.05      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA H200                    On  |   00000000:59:00.0 Off |                    0 |
# | N/A   37C    P0             76W /  700W |       1MiB / 143771MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA H200                    On  |   00000000:5A:00.0 Off |                    0 |
# | N/A   34C    P0             76W /  700W |       1MiB / 143771MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA H200                    On  |   00000000:72:00.0 Off |                    0 |
# | N/A   36C    P0             75W /  700W |       1MiB / 143771MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA H200                    On  |   00000000:73:00.0 Off |                    0 |
# | N/A   33C    P0             75W /  700W |       1MiB / 143771MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   4  NVIDIA H200                    On  |   00000000:8B:00.0 Off |                    0 |
# | N/A   36C    P0             75W /  700W |       1MiB / 143771MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   5  NVIDIA H200                    On  |   00000000:8C:00.0 Off |                    0 |
# | N/A   33C    P0             77W /  700W |       1MiB / 143771MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   6  NVIDIA H200                    On  |   00000000:A4:00.0 Off |                    0 |
# | N/A   36C    P0             80W /  700W |       1MiB / 143771MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
# |   7  NVIDIA H200                    On  |   00000000:A5:00.0 Off |                    0 |
# | N/A   34C    P0             76W /  700W |       1MiB / 143771MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# ## 1. Setup

# %%
# GPU IDs to use for this notebook -- to use a single GPU, set it to [0]
GPUS_TO_USE = [0, 1, 2, 3, 4, 5, 6, 7]

config_file = "experiments/haithamkhedr/fa_sam2_evals/prod_v12_sam2_internal_shared_dth0.5_newdet0.7_assth0.1_nms0.1.multigpu.yaml"
checkpoint_file = "/checkpoint/sam3/haithamkhedr/checkpoints/sam3_dense/prod_v12_sam2_internal_shared_dth0.5_newdet0.7_assth0.1_nms0.1.pt"
hydra_overrides = [
    "trainer.model._target_=onevision.models.detr.sam3_demo_dense_tracking_multigpu.Sam3DenseTrackingDemoMultiGPU",
    "++trainer.model.hotstart_delay=15",
    "++trainer.model.hotstart_unmatch_thresh=8",
    "++trainer.model.hotstart_dup_thresh=8",
    "++trainer.model.compile_model=True",
    # no need to set `ckpt_path` or `sam3_ckpt_path`, as Sam3ModelMultiGPU will handle the checkpoint loading from `checkpoint_file`
    "++trainer.model.ckpt_path=null",
    "++trainer.model.sam3_ckpt_path=null",
    "cluster=fair_sc",
]

# %%
import os
import random
import sys
from glob import glob

sys.path.insert(0, "../../../")
sys.path.insert(0, "../../../../")
os.environ["DVC_LOCK"] = "../../dvc.lock"

# set the GPUs to use via "CUDA_VISIBLE_DEVICES"
assert all(isinstance(i, int) for i in GPUS_TO_USE)
assert GPUS_TO_USE == sorted(set(GPUS_TO_USE))
os.environ["CUDA_VISIBLE_DEVICES"] = ",".join(str(i) for i in GPUS_TO_USE)

# !!! this line needs to be *after* setting "CUDA_VISIBLE_DEVICES" but *before* any torch import !!!
import webdemo.ta.models.sam3_model_multigpu

# the `Sam3ModelMultiGPU` class will spawn worker processes and set up an NCCL process group
model_wrapper = webdemo.ta.models.sam3_model_multigpu.Sam3ModelMultiGPU(
    config_file=config_file,
    checkpoint_file=checkpoint_file,
    hydra_overrides=hydra_overrides,
    strict_state_dict_loading=True,
)
# Out:
# INFO 2025-08-23 00:34:42,010 2386646 sam3_model_multigpu.py:  25: setting up MultiGPU inference with AVAILABLE_GPUS=[0, 1, 2, 3, 4, 5, 6, 7]
# INFO 2025-08-23 00:34:42,011 2386646 sam3_model_multigpu.py:  40: loading model on rank=0 with world_size=8 -- this could take a while ...
# WARNING:root:AsyncVideoFileLoaderWithTorchCodec reached
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading VETextEncoder _IncompatibleKeys(missing_keys=['encoder.text_projection', 'resizer.weight', 'resizer.bias'], unexpected_keys=[])
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# INFO 2025-08-23 00:35:17,009 2386646 sam3_demo_dense_tracking_multigpu.py: 320: 1/3 warming up model compilation
# INFO 2025-08-23 00:35:17,009 2386646 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /storage/home/boxinz/onevision/projects/onevision/notebooks/sam3_dense_tracking/../../../onevision/models/detr/deformable_decoder.py:326: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# INFO 2025-08-23 00:35:17,768 2386646 sam3_demo_dense_tracking_multigpu.py: 322: 1/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:   0%|                                | 0/30 [00:00<?, ?it/s]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video:   7%|█▌                      | 2/30 [00:13<03:15,  6.98s/it]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video:  10%|██▍                     | 3/30 [00:14<01:59,  4.41s/it]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video: 100%|███████████████████████| 30/30 [00:15<00:00,  1.93it/s]
# propagate_in_video: 0it [00:00, ?it/s]
# INFO 2025-08-23 00:35:33,606 2386646 sam3_demo_dense_tracking_multigpu.py: 334: 1/3 warming up model compilation -- completed round 1 out of 3
# INFO 2025-08-23 00:35:33,607 2386646 sam3_demo_dense_tracking_multigpu.py: 320: 2/3 warming up model compilation
# INFO 2025-08-23 00:35:33,607 2386646 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 10
# INFO 2025-08-23 00:35:33,684 2386646 sam3_demo_dense_tracking_multigpu.py: 322: 2/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video: 100%|███████████████████████| 20/20 [00:00<00:00, 36.91it/s]
# propagate_in_video: 100%|███████████████████████| 10/10 [00:00<00:00, 31.63it/s]
# INFO 2025-08-23 00:35:34,769 2386646 sam3_demo_dense_tracking_multigpu.py: 334: 2/3 warming up model compilation -- completed round 2 out of 3
# INFO 2025-08-23 00:35:34,770 2386646 sam3_demo_dense_tracking_multigpu.py: 320: 3/3 warming up model compilation
# INFO 2025-08-23 00:35:34,771 2386646 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 20
# INFO 2025-08-23 00:35:34,846 2386646 sam3_demo_dense_tracking_multigpu.py: 322: 3/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video: 100%|███████████████████████| 10/10 [00:00<00:00, 41.41it/s]
# propagate_in_video: 100%|███████████████████████| 20/20 [00:00<00:00, 33.30it/s]
# INFO 2025-08-23 00:35:35,920 2386646 sam3_demo_dense_tracking_multigpu.py: 334: 3/3 warming up model compilation -- completed round 3 out of 3
# INFO 2025-08-23 00:35:35,921 2386646 sam3_demo_dense_tracking_multigpu.py: 339: Warm-up compilation completed.
# INFO 2025-08-23 00:35:35,923 2386646 sam3_model_multigpu.py:  42: loading model on rank=0 with world_size=8 -- DONE locally
# INFO 2025-08-23 00:35:35,924 2386646 sam3_model_multigpu.py:  86: spawning 8 worker processes
# INFO 2025-08-23 00:35:35,945 2386646 sam3_model_multigpu.py: 113: spawned 8 worker processes
# INFO 2025-08-23 00:35:35,946 2386646 sam3_model_multigpu.py: 121: starting NCCL process group on rank=0 with world_size=8
# INFO 2025-08-23 00:35:37,478 2387161 sam3_model_multigpu.py: 146: starting worker process rank=7 with world_size=8
# INFO 2025-08-23 00:35:37,478 2387156 sam3_model_multigpu.py: 146: starting worker process rank=2 with world_size=8
# INFO 2025-08-23 00:35:37,478 2387161 sam3_model_multigpu.py:  40: loading model on rank=7 with world_size=8 -- this could take a while ...
# INFO 2025-08-23 00:35:37,478 2387160 sam3_model_multigpu.py: 146: starting worker process rank=6 with world_size=8
# INFO 2025-08-23 00:35:37,478 2387156 sam3_model_multigpu.py:  40: loading model on rank=2 with world_size=8 -- this could take a while ...
# INFO 2025-08-23 00:35:37,478 2387160 sam3_model_multigpu.py:  40: loading model on rank=6 with world_size=8 -- this could take a while ...
# INFO 2025-08-23 00:35:37,479 2387157 sam3_model_multigpu.py: 146: starting worker process rank=3 with world_size=8
# INFO 2025-08-23 00:35:37,479 2387157 sam3_model_multigpu.py:  40: loading model on rank=3 with world_size=8 -- this could take a while ...
# INFO 2025-08-23 00:35:37,508 2387159 sam3_model_multigpu.py: 146: starting worker process rank=5 with world_size=8
# INFO 2025-08-23 00:35:37,508 2387159 sam3_model_multigpu.py:  40: loading model on rank=5 with world_size=8 -- this could take a while ...
# INFO 2025-08-23 00:35:37,516 2387155 sam3_model_multigpu.py: 146: starting worker process rank=1 with world_size=8
# INFO 2025-08-23 00:35:37,516 2387155 sam3_model_multigpu.py:  40: loading model on rank=1 with world_size=8 -- this could take a while ...
# INFO 2025-08-23 00:35:37,522 2387158 sam3_model_multigpu.py: 146: starting worker process rank=4 with world_size=8
# INFO 2025-08-23 00:35:37,522 2387158 sam3_model_multigpu.py:  40: loading model on rank=4 with world_size=8 -- this could take a while ...
# WARNING:root:AsyncVideoFileLoaderWithTorchCodec reached
# WARNING:root:AsyncVideoFileLoaderWithTorchCodec reached
# WARNING:root:AsyncVideoFileLoaderWithTorchCodec reached
# WARNING:root:AsyncVideoFileLoaderWithTorchCodec reached
# WARNING:root:AsyncVideoFileLoaderWithTorchCodec reached
# WARNING:root:AsyncVideoFileLoaderWithTorchCodec reached
# WARNING:root:AsyncVideoFileLoaderWithTorchCodec reached
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# INFO 2025-08-23 00:37:37,173 2387159 sam3_demo_dense_tracking_multigpu.py: 320: 1/3 warming up model compilation
# INFO 2025-08-23 00:37:37,173 2387159 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# INFO 2025-08-23 00:37:37,501 2387157 sam3_demo_dense_tracking_multigpu.py: 320: 1/3 warming up model compilation
# INFO 2025-08-23 00:37:37,501 2387157 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# INFO 2025-08-23 00:37:37,626 2387156 sam3_demo_dense_tracking_multigpu.py: 320: 1/3 warming up model compilation
# INFO 2025-08-23 00:37:37,626 2387156 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# /storage/home/boxinz/onevision/projects/onevision/notebooks/sam3_dense_tracking/../../../onevision/models/detr/deformable_decoder.py:326: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# INFO 2025-08-23 00:37:37,920 2387159 sam3_demo_dense_tracking_multigpu.py: 322: 1/3 warming up model compilation with propagation -- this might take a while
# /storage/home/boxinz/onevision/projects/onevision/notebooks/sam3_dense_tracking/../../../onevision/models/detr/deformable_decoder.py:326: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading VETextEncoder _IncompatibleKeys(missing_keys=['encoder.text_projection', 'resizer.weight', 'resizer.bias'], unexpected_keys=[])
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading VETextEncoder _IncompatibleKeys(missing_keys=['encoder.text_projection', 'resizer.weight', 'resizer.bias'], unexpected_keys=[])
# propagate_in_video:   0%|          | 0/30 [00:00<?, ?it/s]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# INFO 2025-08-23 00:37:38,110 2387157 sam3_demo_dense_tracking_multigpu.py: 322: 1/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:   0%|          | 0/30 [00:00<?, ?it/s]/storage/home/boxinz/onevision/projects/onevision/notebooks/sam3_dense_tracking/../../../onevision/models/detr/deformable_decoder.py:326: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# INFO 2025-08-23 00:37:38,357 2387156 sam3_demo_dense_tracking_multigpu.py: 322: 1/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:   0%|          | 0/30 [00:00<?, ?it/s]
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading VETextEncoder _IncompatibleKeys(missing_keys=['encoder.text_projection', 'resizer.weight', 'resizer.bias'], unexpected_keys=[])
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# INFO 2025-08-23 00:37:38,841 2387161 sam3_demo_dense_tracking_multigpu.py: 320: 1/3 warming up model compilation
# INFO 2025-08-23 00:37:38,841 2387161 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /storage/home/boxinz/onevision/projects/onevision/notebooks/sam3_dense_tracking/../../../onevision/models/detr/deformable_decoder.py:326: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# INFO 2025-08-23 00:37:39,577 2387161 sam3_demo_dense_tracking_multigpu.py: 322: 1/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:   0%|          | 0/30 [00:00<?, ?it/s]
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading VETextEncoder _IncompatibleKeys(missing_keys=['encoder.text_projection', 'resizer.weight', 'resizer.bias'], unexpected_keys=[])
# INFO 2025-08-23 00:37:40,769 2387158 sam3_demo_dense_tracking_multigpu.py: 320: 1/3 warming up model compilation
# INFO 2025-08-23 00:37:40,769 2387158 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# INFO 2025-08-23 00:37:41,277 2387160 sam3_demo_dense_tracking_multigpu.py: 320: 1/3 warming up model compilation
# INFO 2025-08-23 00:37:41,277 2387160 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# /storage/home/boxinz/onevision/projects/onevision/notebooks/sam3_dense_tracking/../../../onevision/models/detr/deformable_decoder.py:326: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# INFO 2025-08-23 00:37:41,389 2387155 sam3_demo_dense_tracking_multigpu.py: 320: 1/3 warming up model compilation
# INFO 2025-08-23 00:37:41,389 2387155 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# INFO 2025-08-23 00:37:41,533 2387158 sam3_demo_dense_tracking_multigpu.py: 322: 1/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:   0%|          | 0/30 [00:00<?, ?it/s]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /storage/home/boxinz/onevision/projects/onevision/notebooks/sam3_dense_tracking/../../../onevision/models/detr/deformable_decoder.py:326: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading VETextEncoder _IncompatibleKeys(missing_keys=['encoder.text_projection', 'resizer.weight', 'resizer.bias'], unexpected_keys=[])
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# INFO 2025-08-23 00:37:41,820 2387160 sam3_demo_dense_tracking_multigpu.py: 322: 1/3 warming up model compilation with propagation -- this might take a while
# /storage/home/boxinz/onevision/projects/onevision/notebooks/sam3_dense_tracking/../../../onevision/models/detr/deformable_decoder.py:326: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=False):
# propagate_in_video:   0%|          | 0/30 [00:00<?, ?it/s]
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading VETextEncoder _IncompatibleKeys(missing_keys=['encoder.text_projection', 'resizer.weight', 'resizer.bias'], unexpected_keys=[])
# INFO 2025-08-23 00:37:42,038 2387155 sam3_demo_dense_tracking_multigpu.py: 322: 1/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:   0%|          | 0/30 [00:00<?, ?it/s]
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading ViT _IncompatibleKeys(missing_keys=['blocks.0.attn.freqs_cis', 'blocks.1.attn.freqs_cis', 'blocks.2.attn.freqs_cis', 'blocks.3.attn.freqs_cis', 'blocks.4.attn.freqs_cis', 'blocks.5.attn.freqs_cis', 'blocks.6.attn.freqs_cis', 'blocks.7.attn.freqs_cis', 'blocks.8.attn.freqs_cis', 'blocks.9.attn.freqs_cis', 'blocks.10.attn.freqs_cis', 'blocks.11.attn.freqs_cis', 'blocks.12.attn.freqs_cis', 'blocks.13.attn.freqs_cis', 'blocks.14.attn.freqs_cis', 'blocks.15.attn.freqs_cis', 'blocks.16.attn.freqs_cis', 'blocks.17.attn.freqs_cis', 'blocks.18.attn.freqs_cis', 'blocks.19.attn.freqs_cis', 'blocks.20.attn.freqs_cis', 'blocks.21.attn.freqs_cis', 'blocks.22.attn.freqs_cis', 'blocks.23.attn.freqs_cis', 'blocks.24.attn.freqs_cis', 'blocks.25.attn.freqs_cis', 'blocks.26.attn.freqs_cis', 'blocks.27.attn.freqs_cis', 'blocks.28.attn.freqs_cis', 'blocks.29.attn.freqs_cis', 'blocks.30.attn.freqs_cis', 'blocks.31.attn.freqs_cis'], unexpected_keys=['class_embedding'])
# loading VETextEncoder _IncompatibleKeys(missing_keys=['encoder.text_projection', 'resizer.weight', 'resizer.bias'], unexpected_keys=[])
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video:   7%|▋         | 2/30 [00:14<03:17,  7.05s/it]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video:  10%|█         | 3/30 [00:15<02:02,  4.54s/it]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video: 100%|██████████| 30/30 [00:15<00:00,  1.89it/s]
# propagate_in_video: 0it [00:00, ?it/s]
# propagate_in_video:  10%|█         | 3/30 [00:15<02:09,  4.78s/it]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video:  10%|█         | 3/30 [00:15<02:07,  4.72s/it]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video:  23%|██▎       | 7/30 [00:15<00:32,  1.42s/it]INFO 2025-08-23 00:37:54,126 2387159 sam3_demo_dense_tracking_multigpu.py: 334: 1/3 warming up model compilation -- completed round 1 out of 3
# INFO 2025-08-23 00:37:54,126 2387159 sam3_demo_dense_tracking_multigpu.py: 320: 2/3 warming up model compilation
# INFO 2025-08-23 00:37:54,126 2387159 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 10
# propagate_in_video:  37%|███▋      | 11/30 [00:16<00:13,  1.37it/s]INFO 2025-08-23 00:37:54,202 2387159 sam3_demo_dense_tracking_multigpu.py: 322: 2/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:  10%|█         | 3/30 [00:14<02:01,  4.49s/it]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video: 100%|██████████| 30/30 [00:16<00:00,  1.81it/s]
# propagate_in_video: 0it [00:00, ?it/s]
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 36.97it/s]
# propagate_in_video: 100%|██████████| 30/30 [00:16<00:00,  1.83it/s]
# propagate_in_video: 0it [00:00, ?it/s]
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 33.20it/s]
# INFO 2025-08-23 00:37:55,127 2387157 sam3_demo_dense_tracking_multigpu.py: 334: 1/3 warming up model compilation -- completed round 1 out of 3
# INFO 2025-08-23 00:37:55,128 2387157 sam3_demo_dense_tracking_multigpu.py: 320: 2/3 warming up model compilation
# INFO 2025-08-23 00:37:55,128 2387157 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 10
# propagate_in_video:  77%|███████▋  | 23/30 [00:15<00:01,  5.36it/s]INFO 2025-08-23 00:37:55,160 2387156 sam3_demo_dense_tracking_multigpu.py: 334: 1/3 warming up model compilation -- completed round 1 out of 3
# INFO 2025-08-23 00:37:55,160 2387156 sam3_demo_dense_tracking_multigpu.py: 320: 2/3 warming up model compilation
# INFO 2025-08-23 00:37:55,160 2387156 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 10
# INFO 2025-08-23 00:37:55,207 2387157 sam3_demo_dense_tracking_multigpu.py: 322: 2/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:   0%|          | 0/20 [00:00<?, ?it/s]INFO 2025-08-23 00:37:55,238 2387156 sam3_demo_dense_tracking_multigpu.py: 322: 2/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video: 100%|██████████| 30/30 [00:15<00:00,  1.90it/s]
# propagate_in_video: 0it [00:00, ?it/s]
# INFO 2025-08-23 00:37:55,348 2387159 sam3_demo_dense_tracking_multigpu.py: 334: 2/3 warming up model compilation -- completed round 2 out of 3
# INFO 2025-08-23 00:37:55,348 2387159 sam3_demo_dense_tracking_multigpu.py: 320: 3/3 warming up model compilation
# INFO 2025-08-23 00:37:55,348 2387159 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 20
# propagate_in_video:  25%|██▌       | 5/20 [00:00<00:00, 41.11it/s]INFO 2025-08-23 00:37:55,424 2387159 sam3_demo_dense_tracking_multigpu.py: 322: 3/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 41.20it/s]
# propagate_in_video:   0%|          | 0/20 [00:00<?, ?it/s]INFO 2025-08-23 00:37:55,725 2387161 sam3_demo_dense_tracking_multigpu.py: 334: 1/3 warming up model compilation -- completed round 1 out of 3
# INFO 2025-08-23 00:37:55,725 2387161 sam3_demo_dense_tracking_multigpu.py: 320: 2/3 warming up model compilation
# INFO 2025-08-23 00:37:55,725 2387161 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 10
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 36.46it/s]
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 36.96it/s]
# propagate_in_video:  15%|█▌        | 3/20 [00:00<00:00, 25.06it/s]INFO 2025-08-23 00:37:55,805 2387161 sam3_demo_dense_tracking_multigpu.py: 322: 2/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:  70%|███████   | 7/10 [00:00<00:00, 29.87it/s]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 33.19it/s]
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 33.63it/s]
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 33.19it/s]
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 36.75it/s]
# propagate_in_video:   0%|          | 0/10 [00:00<?, ?it/s]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video:  30%|███       | 3/10 [00:00<00:00, 24.89it/s]INFO 2025-08-23 00:37:56,490 2387157 sam3_demo_dense_tracking_multigpu.py: 334: 2/3 warming up model compilation -- completed round 2 out of 3
# INFO 2025-08-23 00:37:56,490 2387157 sam3_demo_dense_tracking_multigpu.py: 320: 3/3 warming up model compilation
# INFO 2025-08-23 00:37:56,490 2387157 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 20
# INFO 2025-08-23 00:37:56,519 2387156 sam3_demo_dense_tracking_multigpu.py: 334: 2/3 warming up model compilation -- completed round 2 out of 3
# INFO 2025-08-23 00:37:56,519 2387156 sam3_demo_dense_tracking_multigpu.py: 320: 3/3 warming up model compilation
# INFO 2025-08-23 00:37:56,520 2387156 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 20
# propagate_in_video:  10%|█         | 3/30 [00:14<02:01,  4.49s/it]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# INFO 2025-08-23 00:37:56,568 2387157 sam3_demo_dense_tracking_multigpu.py: 322: 3/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:   0%|          | 0/10 [00:00<?, ?it/s]INFO 2025-08-23 00:37:56,572 2387159 sam3_demo_dense_tracking_multigpu.py: 334: 3/3 warming up model compilation -- completed round 3 out of 3
# INFO 2025-08-23 00:37:56,572 2387159 sam3_demo_dense_tracking_multigpu.py: 339: Warm-up compilation completed.
# INFO 2025-08-23 00:37:56,574 2387159 sam3_model_multigpu.py:  42: loading model on rank=5 with world_size=8 -- DONE locally
# INFO 2025-08-23 00:37:56,574 2387159 sam3_model_multigpu.py: 121: starting NCCL process group on rank=5 with world_size=8
# [W823 00:37:56.604935520 Utils.hpp:137] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function operator())
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video:  70%|███████   | 7/10 [00:00<00:00, 29.72it/s]INFO 2025-08-23 00:37:56,597 2387156 sam3_demo_dense_tracking_multigpu.py: 322: 3/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 33.09it/s]
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 40.81it/s]
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 41.29it/s]
# propagate_in_video:  15%|█▌        | 3/20 [00:00<00:00, 25.29it/s]INFO 2025-08-23 00:37:56,967 2387161 sam3_demo_dense_tracking_multigpu.py: 334: 2/3 warming up model compilation -- completed round 2 out of 3
# INFO 2025-08-23 00:37:56,967 2387161 sam3_demo_dense_tracking_multigpu.py: 320: 3/3 warming up model compilation
# INFO 2025-08-23 00:37:56,967 2387161 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 20
# propagate_in_video:  63%|██████▎   | 19/30 [00:15<00:02,  3.70it/s]INFO 2025-08-23 00:37:57,044 2387161 sam3_demo_dense_tracking_multigpu.py: 322: 3/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:  10%|█         | 3/30 [00:15<02:05,  4.65s/it]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video:  10%|█         | 3/30 [00:15<02:04,  4.59s/it]/checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 41.41it/s]
# propagate_in_video: 100%|██████████| 30/30 [00:15<00:00,  1.90it/s]
# propagate_in_video: 0it [00:00, ?it/s]
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 33.18it/s]
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 33.56it/s]
# propagate_in_video:  50%|█████     | 15/30 [00:15<00:06,  2.34it/s]INFO 2025-08-23 00:37:57,634 2387158 sam3_demo_dense_tracking_multigpu.py: 334: 1/3 warming up model compilation -- completed round 1 out of 3
# INFO 2025-08-23 00:37:57,634 2387158 sam3_demo_dense_tracking_multigpu.py: 320: 2/3 warming up model compilation
# INFO 2025-08-23 00:37:57,634 2387158 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 10
# propagate_in_video:  63%|██████▎   | 19/30 [00:15<00:03,  3.59it/s]INFO 2025-08-23 00:37:57,711 2387158 sam3_demo_dense_tracking_multigpu.py: 322: 2/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:  77%|███████▋  | 23/30 [00:15<00:01,  5.21it/s]INFO 2025-08-23 00:37:57,804 2387157 sam3_demo_dense_tracking_multigpu.py: 334: 3/3 warming up model compilation -- completed round 3 out of 3
# INFO 2025-08-23 00:37:57,804 2387157 sam3_demo_dense_tracking_multigpu.py: 339: Warm-up compilation completed.
# INFO 2025-08-23 00:37:57,811 2387157 sam3_model_multigpu.py:  42: loading model on rank=3 with world_size=8 -- DONE locally
# INFO 2025-08-23 00:37:57,812 2387157 sam3_model_multigpu.py: 121: starting NCCL process group on rank=3 with world_size=8
# [W823 00:37:57.842754663 Utils.hpp:137] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function operator())
# INFO 2025-08-23 00:37:57,823 2387156 sam3_demo_dense_tracking_multigpu.py: 334: 3/3 warming up model compilation -- completed round 3 out of 3
# INFO 2025-08-23 00:37:57,823 2387156 sam3_demo_dense_tracking_multigpu.py: 339: Warm-up compilation completed.
# INFO 2025-08-23 00:37:57,825 2387156 sam3_model_multigpu.py:  42: loading model on rank=2 with world_size=8 -- DONE locally
# INFO 2025-08-23 00:37:57,826 2387156 sam3_model_multigpu.py: 121: starting NCCL process group on rank=2 with world_size=8
# [W823 00:37:57.855996774 Utils.hpp:137] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function operator())
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 33.26it/s]
# propagate_in_video: 100%|██████████| 30/30 [00:16<00:00,  1.86it/s]
# propagate_in_video: 0it [00:00, ?it/s]
# propagate_in_video: 100%|██████████| 30/30 [00:16<00:00,  1.87it/s]
# propagate_in_video: 0it [00:00, ?it/s]
# propagate_in_video:  70%|███████   | 14/20 [00:00<00:00, 35.03it/s]INFO 2025-08-23 00:37:58,201 2387161 sam3_demo_dense_tracking_multigpu.py: 334: 3/3 warming up model compilation -- completed round 3 out of 3
# INFO 2025-08-23 00:37:58,201 2387161 sam3_demo_dense_tracking_multigpu.py: 339: Warm-up compilation completed.
# INFO 2025-08-23 00:37:58,203 2387161 sam3_model_multigpu.py:  42: loading model on rank=7 with world_size=8 -- DONE locally
# INFO 2025-08-23 00:37:58,203 2387161 sam3_model_multigpu.py: 121: starting NCCL process group on rank=7 with world_size=8
# [W823 00:37:58.234133329 Utils.hpp:137] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function operator())
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 36.94it/s]
# propagate_in_video:   0%|          | 0/10 [00:00<?, ?it/s]INFO 2025-08-23 00:37:58,337 2387160 sam3_demo_dense_tracking_multigpu.py: 334: 1/3 warming up model compilation -- completed round 1 out of 3
# INFO 2025-08-23 00:37:58,337 2387160 sam3_demo_dense_tracking_multigpu.py: 320: 2/3 warming up model compilation
# INFO 2025-08-23 00:37:58,337 2387160 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 10
# propagate_in_video:  30%|███       | 3/10 [00:00<00:00, 25.11it/s]INFO 2025-08-23 00:37:58,399 2387155 sam3_demo_dense_tracking_multigpu.py: 334: 1/3 warming up model compilation -- completed round 1 out of 3
# INFO 2025-08-23 00:37:58,399 2387155 sam3_demo_dense_tracking_multigpu.py: 320: 2/3 warming up model compilation
# INFO 2025-08-23 00:37:58,399 2387155 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 10
# INFO 2025-08-23 00:37:58,413 2387160 sam3_demo_dense_tracking_multigpu.py: 322: 2/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:   0%|          | 0/20 [00:00<?, ?it/s]INFO 2025-08-23 00:37:58,475 2387155 sam3_demo_dense_tracking_multigpu.py: 322: 2/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 33.38it/s]
# propagate_in_video:  70%|███████   | 14/20 [00:00<00:00, 35.19it/s]INFO 2025-08-23 00:37:58,859 2387158 sam3_demo_dense_tracking_multigpu.py: 334: 2/3 warming up model compilation -- completed round 2 out of 3
# INFO 2025-08-23 00:37:58,859 2387158 sam3_demo_dense_tracking_multigpu.py: 320: 3/3 warming up model compilation
# INFO 2025-08-23 00:37:58,859 2387158 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 20
# propagate_in_video:  90%|█████████ | 18/20 [00:00<00:00, 34.53it/s]INFO 2025-08-23 00:37:58,936 2387158 sam3_demo_dense_tracking_multigpu.py: 322: 3/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 37.10it/s]
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 37.06it/s]
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 41.59it/s]
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 33.39it/s]
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 33.49it/s]
# propagate_in_video:  55%|█████▌    | 11/20 [00:00<00:00, 31.58it/s]INFO 2025-08-23 00:37:59,613 2387160 sam3_demo_dense_tracking_multigpu.py: 334: 2/3 warming up model compilation -- completed round 2 out of 3
# INFO 2025-08-23 00:37:59,614 2387160 sam3_demo_dense_tracking_multigpu.py: 320: 3/3 warming up model compilation
# INFO 2025-08-23 00:37:59,614 2387160 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 20
# INFO 2025-08-23 00:37:59,647 2387155 sam3_demo_dense_tracking_multigpu.py: 334: 2/3 warming up model compilation -- completed round 2 out of 3
# INFO 2025-08-23 00:37:59,647 2387155 sam3_demo_dense_tracking_multigpu.py: 320: 3/3 warming up model compilation
# INFO 2025-08-23 00:37:59,647 2387155 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 20
# propagate_in_video:  75%|███████▌  | 15/20 [00:00<00:00, 32.32it/s]INFO 2025-08-23 00:37:59,690 2387160 sam3_demo_dense_tracking_multigpu.py: 322: 3/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video:   0%|          | 0/10 [00:00<?, ?it/s]INFO 2025-08-23 00:37:59,723 2387155 sam3_demo_dense_tracking_multigpu.py: 322: 3/3 warming up model compilation with propagation -- this might take a while
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 33.40it/s]
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 41.69it/s]
# propagate_in_video: 100%|██████████| 10/10 [00:00<00:00, 41.58it/s]
# propagate_in_video:  15%|█▌        | 3/20 [00:00<00:00, 25.24it/s]INFO 2025-08-23 00:38:00,074 2387158 sam3_demo_dense_tracking_multigpu.py: 334: 3/3 warming up model compilation -- completed round 3 out of 3
# INFO 2025-08-23 00:38:00,074 2387158 sam3_demo_dense_tracking_multigpu.py: 339: Warm-up compilation completed.
# INFO 2025-08-23 00:38:00,076 2387158 sam3_model_multigpu.py:  42: loading model on rank=4 with world_size=8 -- DONE locally
# INFO 2025-08-23 00:38:00,076 2387158 sam3_model_multigpu.py: 121: starting NCCL process group on rank=4 with world_size=8
# [W823 00:38:00.107317595 Utils.hpp:137] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function operator())
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 33.46it/s]
# propagate_in_video: 100%|██████████| 20/20 [00:00<00:00, 33.42it/s]
# INFO 2025-08-23 00:38:00,888 2387160 sam3_demo_dense_tracking_multigpu.py: 334: 3/3 warming up model compilation -- completed round 3 out of 3
# INFO 2025-08-23 00:38:00,888 2387160 sam3_demo_dense_tracking_multigpu.py: 339: Warm-up compilation completed.
# INFO 2025-08-23 00:38:00,895 2387155 sam3_demo_dense_tracking_multigpu.py: 334: 3/3 warming up model compilation -- completed round 3 out of 3
# INFO 2025-08-23 00:38:00,895 2387155 sam3_demo_dense_tracking_multigpu.py: 339: Warm-up compilation completed.
# INFO 2025-08-23 00:38:00,896 2387160 sam3_model_multigpu.py:  42: loading model on rank=6 with world_size=8 -- DONE locally
# INFO 2025-08-23 00:38:00,896 2387160 sam3_model_multigpu.py: 121: starting NCCL process group on rank=6 with world_size=8
# [W823 00:38:00.927185986 Utils.hpp:137] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function operator())
# INFO 2025-08-23 00:38:00,902 2387155 sam3_model_multigpu.py:  42: loading model on rank=1 with world_size=8 -- DONE locally
# INFO 2025-08-23 00:38:00,902 2387155 sam3_model_multigpu.py: 121: starting NCCL process group on rank=1 with world_size=8
# [W823 00:38:00.933377300 Utils.hpp:137] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function operator())
# [W823 00:38:00.941984724 Utils.hpp:137] Warning: Environment variable NCCL_ASYNC_ERROR_HANDLING is deprecated; use TORCH_NCCL_ASYNC_ERROR_HANDLING instead (function operator())
# INFO 2025-08-23 00:38:00,917 2386646 sam3_model_multigpu.py: 130: started NCCL process group on rank=0 with world_size=8
# INFO 2025-08-23 00:38:00,918 2386646 sam3_model_multigpu.py:  50: loading model on rank=0 with world_size=8 -- DONE on all ranks
# INFO 2025-08-23 00:38:00,920 2387158 sam3_model_multigpu.py: 130: started NCCL process group on rank=4 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387158 sam3_model_multigpu.py:  50: loading model on rank=4 with world_size=8 -- DONE on all ranks
# INFO 2025-08-23 00:38:00,920 2387158 sam3_model_multigpu.py: 148: started worker rank=4 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387155 sam3_model_multigpu.py: 130: started NCCL process group on rank=1 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387161 sam3_model_multigpu.py: 130: started NCCL process group on rank=7 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387156 sam3_model_multigpu.py: 130: started NCCL process group on rank=2 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387155 sam3_model_multigpu.py:  50: loading model on rank=1 with world_size=8 -- DONE on all ranks
# INFO 2025-08-23 00:38:00,920 2387156 sam3_model_multigpu.py:  50: loading model on rank=2 with world_size=8 -- DONE on all ranks
# INFO 2025-08-23 00:38:00,920 2387157 sam3_model_multigpu.py: 130: started NCCL process group on rank=3 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387161 sam3_model_multigpu.py:  50: loading model on rank=7 with world_size=8 -- DONE on all ranks
# INFO 2025-08-23 00:38:00,920 2387160 sam3_model_multigpu.py: 130: started NCCL process group on rank=6 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387155 sam3_model_multigpu.py: 148: started worker rank=1 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387156 sam3_model_multigpu.py: 148: started worker rank=2 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387161 sam3_model_multigpu.py: 148: started worker rank=7 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387157 sam3_model_multigpu.py:  50: loading model on rank=3 with world_size=8 -- DONE on all ranks
# INFO 2025-08-23 00:38:00,920 2387159 sam3_model_multigpu.py: 130: started NCCL process group on rank=5 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387160 sam3_model_multigpu.py:  50: loading model on rank=6 with world_size=8 -- DONE on all ranks
# INFO 2025-08-23 00:38:00,920 2387157 sam3_model_multigpu.py: 148: started worker rank=3 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387160 sam3_model_multigpu.py: 148: started worker rank=6 with world_size=8
# INFO 2025-08-23 00:38:00,920 2387159 sam3_model_multigpu.py:  50: loading model on rank=5 with world_size=8 -- DONE on all ranks
# INFO 2025-08-23 00:38:00,920 2387159 sam3_model_multigpu.py: 148: started worker rank=5 with world_size=8
# INFO 2025-08-23 00:59:43,718 2386646 sam3_model.py: 308: removed expired session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14440 MiB used and 17226 MiB reserved (max over time: 14472 MiB used and 17226 MiB reserved)
# INFO 2025-08-23 01:00:44,076 2386646 sam3_model.py: 308: removed expired session 2bf62b17-b089-45e6-8b0e-d052e6fd698d; live sessions: ['f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 11347 MiB used and 17226 MiB reserved (max over time: 14472 MiB used and 17226 MiB reserved)
# INFO 2025-08-23 01:01:14,388 2386646 sam3_model.py: 308: removed expired session f948a2c7-533f-4e59-8abc-f11937b7a600; live sessions: ['2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 9777 MiB used and 17226 MiB reserved (max over time: 14472 MiB used and 17226 MiB reserved)
# INFO 2025-08-23 01:01:44,699 2386646 sam3_model.py: 308: removed expired session 2fc95f85-2422-45e6-a946-96fdeab386e7; live sessions: ['3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 8206 MiB used and 17226 MiB reserved (max over time: 14472 MiB used and 17226 MiB reserved)
# INFO 2025-08-23 01:02:14,987 2386646 sam3_model.py: 308: removed expired session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: [], GPU memory: 6635 MiB used and 17226 MiB reserved (max over time: 14472 MiB used and 17226 MiB reserved)

# %% [markdown]
# ### Visualization utils

# %%
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import numpy as np
import pprint
import cv2
import subprocess
import torch
from matplotlib.colors import to_rgb
from matplotlib.patches import Rectangle
from PIL import Image
from skimage.color import rgb2lab, lab2rgb
from sklearn.cluster import KMeans
from tqdm import tqdm
from onevision.utils.misc import interpolate
from omnivision.utils.generic import recursive_to
from torchvision.ops import masks_to_boxes


def generate_colors(n_colors=256, n_samples=5000):
    # Step 1: Random RGB samples
    np.random.seed(42)
    rgb = np.random.rand(n_samples, 3)
    # Step 2: Convert to LAB for perceptual uniformity
    print(f"Converting {n_samples} RGB samples to LAB color space...")
    lab = rgb2lab(rgb.reshape(1, -1, 3)).reshape(-1, 3)
    print("Conversion to LAB complete.")
    # Step 3: k-means clustering in LAB
    kmeans = KMeans(n_clusters=n_colors, n_init=10)
    print(f"Fitting KMeans with {n_colors} clusters on {n_samples} samples...")
    kmeans.fit(lab)
    print("KMeans fitting complete.")
    centers_lab = kmeans.cluster_centers_
    # Step 4: Convert LAB back to RGB
    colors_rgb = lab2rgb(centers_lab.reshape(1, -1, 3)).reshape(-1, 3)
    colors_rgb = np.clip(colors_rgb, 0, 1)
    return colors_rgb


COLORS = generate_colors(n_colors=128, n_samples=5000)


def show_img_tensor(img_batch, vis_img_idx=0):
    MEAN_IMG = np.array([0.485, 0.456, 0.406])
    STD_IMG = np.array([0.229, 0.224, 0.225])
    im_tensor = img_batch[vis_img_idx].detach().cpu()
    assert im_tensor.dim() == 3
    im_tensor = im_tensor.numpy().transpose((1, 2, 0))
    im_tensor = (im_tensor * STD_IMG) + MEAN_IMG
    im_tensor = np.clip(im_tensor, 0, 1)
    plt.imshow(im_tensor)


def show_points_with_labels(coords, labels, ax=None, marker_size=200):
    if ax is None:
        ax = plt.gca()
    pos_points = coords[labels==1]
    neg_points = coords[labels==0]
    ax.scatter(pos_points[:, 0], pos_points[:, 1], color="green", marker="*", s=marker_size, edgecolor="white", linewidth=1.25)
    ax.scatter(neg_points[:, 0], neg_points[:, 1], color="red", marker="*", s=marker_size, edgecolor="white", linewidth=1.25)


def plot_bbox(
    img_height,
    img_width,
    box,
    box_format="XYXY",
    relative_coords=True,
    color="r",
    linestyle="solid",
    text=None,
    ax=None,
):
    if box_format == "XYXY":
        x, y, x2, y2 = box
        w = x2 - x
        h = y2 - y
    elif box_format == "XYWH":
        x, y, w, h = box
    elif box_format == "CxCyWH":
        cx, cy, w, h = box
        x = cx - w / 2
        y = cy - h / 2
    else:
        raise RuntimeError(f"Invalid box_format {box_format}")

    if relative_coords:
        x *= img_width
        w *= img_width
        y *= img_height
        h *= img_height

    if ax is None:
        ax = plt.gca()    
    rect = patches.Rectangle(
        (x, y), w, h, linewidth=1.5, edgecolor=color, facecolor="none", linestyle=linestyle,
    )
    ax.add_patch(rect)
    if text is not None:
        facecolor = "w"
        ax.text(
            x, y - 5, text, color=color, weight="bold", fontsize=8,
            bbox={"facecolor": facecolor, "alpha": 0.75, "pad": 2},
        )


def plot_mask(mask, color="r", ax=None):
    im_h, im_w = mask.shape
    mask_img = np.zeros((im_h, im_w, 4), dtype=np.float32)
    mask_img[..., :3] = to_rgb(color)
    mask_img[..., 3] = mask * 0.5
    # Use the provided ax or the current axis
    if ax is None:
        ax = plt.gca()
    ax.imshow(mask_img)


def normalize_bbox(bbox_xyxy, img_w, img_h):
    bbox_xyxy[0], bbox_xyxy[2] = bbox_xyxy[0] / img_w, bbox_xyxy[2] / img_w
    bbox_xyxy[1], bbox_xyxy[3] = bbox_xyxy[1] / img_h, bbox_xyxy[3] / img_h
    return bbox_xyxy

def visualize_frame_output(frame_idx, image_files, outputs, figsize=(12, 8)):
    plt.figure(figsize=figsize)
    plt.title(f"frame {frame_idx}")
    img = plt.imread(image_files[frame_idx])
    img_H, img_W, _ = img.shape
    plt.imshow(img)
    for i in range(len(outputs["out_probs"])):
        box_xywh = outputs["out_boxes_xywh"][i]
        prob = outputs["out_probs"][i]
        obj_id = outputs["out_obj_ids"][i]
        binary_mask = outputs["out_binary_masks"][i]
        color = COLORS[obj_id % len(COLORS)]
        plot_bbox(img_H, img_W, box_xywh, text=f"(id={obj_id}, {prob=:.2f})", box_format="XYWH", color=color)
        plot_mask(binary_mask, color=color)


def visualize_formatted_frame_output(frame_idx, image_files, outputs_list, titles=None, points_list=None, points_labels_list=None, figsize=(12, 8)):
    """Visualize up to three sets of segmentation masks on a video frame.
    
    outputs_list: List of {frame_idx: {obj_id: mask_tensor}}
    titles: List of titles for each set of outputs_list
    """
    num_outputs = len(outputs_list)
    if titles is None:
        titles = [f"Set {i+1}" for i in range(num_outputs)]
    assert len(titles) == num_outputs, "length of `titles` should match that of `outputs_list` if not None."
    
    fig, axes = plt.subplots(1, num_outputs, figsize=figsize)
    if num_outputs == 1:
        axes = [axes]  # Make it iterable
    img = plt.imread(image_files[frame_idx])
    img_H, img_W, _ = img.shape
    for idx in range(num_outputs):
        ax, outputs_set, ax_title = axes[idx], outputs_list[idx], titles[idx]
        ax.set_title(f"Frame {frame_idx} - {ax_title}")
        ax.imshow(img)
        _outputs = outputs_set[frame_idx]
        for obj_id, binary_mask in _outputs.items():
            box_xyxy = masks_to_boxes(torch.tensor(binary_mask).unsqueeze(0)).squeeze()
            box_xyxy = normalize_bbox(box_xyxy, img_W, img_H)
            color = COLORS[obj_id % len(COLORS)]
            plot_bbox(img_H, img_W, box_xyxy, text=f"(id={obj_id})", box_format="XYXY", color=color, ax=ax)
            plot_mask(binary_mask, color=color, ax=ax)

        # points
        if points_list is not None and points_list[idx] is not None:
            show_points_with_labels(points_list[idx], points_labels_list[idx], ax=ax, marker_size=200)
        
    plt.tight_layout()
    plt.show()
        

def render_masklet_frame(img, outputs, frame_idx=None, alpha=0.5):
    """
    Overlays masklets and bounding boxes on a single image frame.
    Args:
        img: np.ndarray, shape (H, W, 3), uint8 or float32 in [0,255] or [0,1]
        outputs: dict with keys: out_boxes_xywh, out_probs, out_obj_ids, out_binary_masks
        frame_idx: int or None, for overlaying frame index text
        alpha: float, mask overlay alpha
    Returns:
        overlay: np.ndarray, shape (H, W, 3), uint8
    """
    if img.dtype == np.float32 or img.max() <= 1.0:
        img = (img * 255).astype(np.uint8)
    img = img[..., :3]  # drop alpha if present
    height, width = img.shape[:2]
    overlay = img.copy()

    for i in range(len(outputs["out_probs"])):
        obj_id = outputs["out_obj_ids"][i]
        color = COLORS[obj_id % len(COLORS)]
        color255 = (color * 255).astype(np.uint8)
        mask = outputs["out_binary_masks"][i]
        if mask.shape != img.shape[:2]:
            mask = cv2.resize(mask.astype(np.float32), (img.shape[1], img.shape[0]), interpolation=cv2.INTER_NEAREST)
        mask_bool = mask > 0.5
        for c in range(3):
            overlay[..., c][mask_bool] = (
                alpha * color255[c] + (1 - alpha) * overlay[..., c][mask_bool]
            ).astype(np.uint8)

    # Draw bounding boxes and text
    for i in range(len(outputs["out_probs"])):
        box_xywh = outputs["out_boxes_xywh"][i]
        obj_id = outputs["out_obj_ids"][i]
        prob = outputs["out_probs"][i]
        color = COLORS[obj_id % len(COLORS)]
        color255 = tuple(int(x * 255) for x in color)
        x, y, w, h = box_xywh
        x1 = int(x * width)
        y1 = int(y * height)
        x2 = int((x + w) * width)
        y2 = int((y + h) * height)
        cv2.rectangle(overlay, (x1, y1), (x2, y2), color255, 2)
        label = f"id={obj_id}, p={prob:.2f}"
        cv2.putText(
            overlay, label, (x1, max(y1 - 10, 0)),
            cv2.FONT_HERSHEY_SIMPLEX, 0.5, color255, 1, cv2.LINE_AA
        )

    # Overlay frame index at the top-left corner
    if frame_idx is not None:
        cv2.putText(
            overlay, f"Frame {frame_idx}", (10, 30),
            cv2.FONT_HERSHEY_SIMPLEX, 1.0, (255, 255, 255), 2, cv2.LINE_AA
        )

    return overlay


def save_masklet_video(image_files, outputs, out_path, alpha=0.5, fps=10):
    # Each outputs dict has keys: "out_boxes_xywh", "out_probs", "out_obj_ids", "out_binary_masks"
    # image_files: list of image file paths, same length as outputs_list

    # Read first frame to get size
    first_img = plt.imread(image_files[0])
    height, width = first_img.shape[:2]
    if first_img.dtype == np.float32 or first_img.max() <= 1.0:
        first_img = (first_img * 255).astype(np.uint8)
    # Use 'mp4v' for best compatibility with VSCode playback (.mp4 files)
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    writer = cv2.VideoWriter('temp.mp4', fourcc, fps, (width, height))

    outputs_list = [(image_files[frame_idx], frame_idx, outputs[frame_idx]) for frame_idx in sorted(outputs.keys())]

    for img_path, frame_idx, frame_outputs in tqdm(outputs_list):
        img = plt.imread(img_path)
        overlay = render_masklet_frame(img, frame_outputs, frame_idx=frame_idx, alpha=alpha)
        writer.write(cv2.cvtColor(overlay, cv2.COLOR_RGB2BGR))

    writer.release()

    # Re-encode the video for VSCode compatibility using ffmpeg
    subprocess.run(["ffmpeg", "-y", "-i", 'temp.mp4', out_path])
    print(f"Re-encoded video saved to {out_path}")

    os.remove('temp.mp4')  # Clean up temporary file


def save_masklet_image(image_file, outputs, out_path, alpha=0.5, frame_idx=None):
    '''
    Save a single image with masklet overlays.
    '''
    img = plt.imread(image_file)
    overlay = render_masklet_frame(img, outputs, frame_idx=frame_idx, alpha=alpha)
    Image.fromarray(overlay).save(out_path)
    print(f"Overlay image saved to {out_path}")


def prepare_masks_for_visualization(frame_to_output):
    # frame_to_obj_masks --> {frame_idx: {'output_probs': np.array, `out_obj_ids`: np.array, `out_binary_masks`: np.array}}
    for frame_idx, out in frame_to_output.items():
        _processed_out = {}
        for idx, obj_id in enumerate(out["out_obj_ids"].tolist()):
            if out["out_binary_masks"][idx].any():
                _processed_out[obj_id] = out["out_binary_masks"][idx]
        frame_to_output[frame_idx] = _processed_out
    return frame_to_output
# Out:
# Converting 5000 RGB samples to LAB color space...
# Conversion to LAB complete.
# Fitting KMeans with 128 clusters on 5000 samples...
# KMeans fitting complete.

# %% [markdown]
# ## 2. Running inference

# %%
# this video has 6 objects
video_frames_dir = "/checkpoint/sam3/shared/webdemo/data/ta/static/gallery/selected_examples/0001/rgb"
prompt_text_str = "person"

# this video has ~80 objects
# video_frames_dir = "/checkpoint/sam3/shared/webdemo/data/ta/static/gallery/selected_examples/0018/rgb"
# prompt_text_str = "horse"


new_video_frames = "/checkpoint/sam3/shared/webdemo/data/ta/static/gallery/selected_examples/0001/video.mp4"
new_prompt_text_str = "person"

# %% [markdown]
# ### Opening an inference session on this video

# %%
response = model_wrapper.handle_request(
    request=dict(
        type="start_session",
        resource_path=new_video_frames,
    )
)
session_id = response["session_id"]

# "image_files" is only needed for visualization purposes (not used by the model)
image_files = glob(os.path.join(new_video_frames, "*.jpg"))
try:
    # integer sort instead of string sort (so that e.g. "2.jpg" is before "11.jpg")
    image_files.sort(key=lambda p: int(os.path.splitext(os.path.basename(p))[0]))
except ValueError:
    # fallback to lexicographic sort if the format is not "<frame_index>.jpg"
    print(
        f'frame names are not in "<frame_index>.jpg" format: {image_files[:5]=}, '
        f"falling back to lexicographic sort."
    )
    image_files.sort()
# Out:
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# INFO 2025-08-23 00:41:46,001 2387156 sam3_model_multigpu.py: 154: worker rank=2 received request request['type']='start_session'
# INFO 2025-08-23 00:41:46,001 2387157 sam3_model_multigpu.py: 154: worker rank=3 received request request['type']='start_session'
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# INFO 2025-08-23 00:41:46,002 2387155 sam3_model_multigpu.py: 154: worker rank=1 received request request['type']='start_session'
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# INFO 2025-08-23 00:41:46,002 2387159 sam3_model_multigpu.py: 154: worker rank=5 received request request['type']='start_session'
# INFO 2025-08-23 00:41:46,002 2387158 sam3_model_multigpu.py: 154: worker rank=4 received request request['type']='start_session'
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# INFO 2025-08-23 00:41:46,002 2387160 sam3_model_multigpu.py: 154: worker rank=6 received request request['type']='start_session'
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# INFO 2025-08-23 00:41:46,003 2387161 sam3_model_multigpu.py: 154: worker rank=7 received request request['type']='start_session'
# WARNING:root:load_resource_as_video_frames reached - use_torchcodec set to True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# WARNING:root:load_video_frames reached - use_torchCodec = True
# frame loading (MP4 w/ GPU):   0%|          | 1/270 [00:00<01:58,  2.27it/s]WARNING:root:AsyncVideoFileLoaderWithTorchCodec init takes 0.4602360725402832seconds
# frame loading (MP4 w/ GPU):   0%|          | 1/270 [00:00<02:07,  2.11it/s]WARNING:root:AsyncVideoFileLoaderWithTorchCodec init takes 0.4931907653808594seconds
# frame loading (MP4 w/ GPU):   0%|          | 1/270 [00:00<02:12,  2.04it/s]WARNING:root:AsyncVideoFileLoaderWithTorchCodec init takes 0.5109789371490479seconds
# frame loading (MP4 w/ GPU):   0%|          | 1/270 [00:00<02:12,  2.03it/s]WARNING:root:AsyncVideoFileLoaderWithTorchCodec init takes 0.5126388072967529seconds
# frame loading (MP4 w/ GPU):   0%|               | 1/270 [00:00<02:14,  2.01it/s]WARNING:root:AsyncVideoFileLoaderWithTorchCodec init takes 0.52555251121521seconds
# INFO 2025-08-23 00:41:46,535 2387156 sam3_model.py: 157: started new session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames), '2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14442 MiB used and 17242 MiB reserved (max over time: 14471 MiB used and 17242 MiB reserved); torch: 2.7.0+cu126 with CUDA arch ['sm_50', 'sm_60', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90'], GPU device: _CudaDeviceProperties(name='NVIDIA H200', major=9, minor=0, total_memory=143186MB, multi_processor_count=132, uuid=b7e00bd2-5da0-e305-9612-989b73e74b40, L2_cache_size=60MB)
# frame loading (MP4 w/ GPU):   0%|          | 1/270 [00:00<02:16,  1.97it/s]WARNING:root:AsyncVideoFileLoaderWithTorchCodec init takes 0.5354759693145752seconds
# frame loading (MP4 w/ GPU):   0%|          | 1/270 [00:00<02:17,  1.96it/s]WARNING:root:AsyncVideoFileLoaderWithTorchCodec init takes 0.5380489826202393seconds
# frame loading (MP4 w/ GPU):   0%|          | 1/270 [00:00<02:20,  1.92it/s]WARNING:root:AsyncVideoFileLoaderWithTorchCodec init takes 0.5413718223571777seconds
# INFO 2025-08-23 00:41:46,558 2387161 sam3_model.py: 157: started new session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames), '2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14149 MiB used and 17118 MiB reserved (max over time: 14178 MiB used and 17118 MiB reserved); torch: 2.7.0+cu126 with CUDA arch ['sm_50', 'sm_60', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90'], GPU device: _CudaDeviceProperties(name='NVIDIA H200', major=9, minor=0, total_memory=143186MB, multi_processor_count=132, uuid=bb879de6-752b-6360-2930-703891b16f7b, L2_cache_size=60MB)
# frame loading (MP4 w/ GPU):  39%|███▊      | 104/270 [00:00<00:00, 253.78it/s]INFO 2025-08-23 00:41:46,578 2387158 sam3_model.py: 157: started new session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames), '2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14276 MiB used and 17224 MiB reserved (max over time: 14299 MiB used and 17224 MiB reserved); torch: 2.7.0+cu126 with CUDA arch ['sm_50', 'sm_60', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90'], GPU device: _CudaDeviceProperties(name='NVIDIA H200', major=9, minor=0, total_memory=143186MB, multi_processor_count=132, uuid=7012294a-dc8c-f99a-5f99-766390fa0ef5, L2_cache_size=60MB)
# INFO 2025-08-23 00:41:46,584 2387155 sam3_model.py: 157: started new session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames), '2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14442 MiB used and 17314 MiB reserved (max over time: 14471 MiB used and 17314 MiB reserved); torch: 2.7.0+cu126 with CUDA arch ['sm_50', 'sm_60', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90'], GPU device: _CudaDeviceProperties(name='NVIDIA H200', major=9, minor=0, total_memory=143186MB, multi_processor_count=132, uuid=8716553a-301d-5a2d-8da9-b00f8ffc3ae9, L2_cache_size=60MB)
# frame loading (MP4 w/ GPU):  39%|███▉      | 106/270 [00:00<00:00, 243.90it/s]INFO 2025-08-23 00:41:46,606 2386646 sam3_model.py: 157: started new session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames), '2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14443 MiB used and 17226 MiB reserved (max over time: 14472 MiB used and 17226 MiB reserved); torch: 2.7.0+cu126 with CUDA arch ['sm_50', 'sm_60', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90'], GPU device: _CudaDeviceProperties(name='NVIDIA H200', major=9, minor=0, total_memory=143186MB, multi_processor_count=132, uuid=3a09078e-8527-3d6c-9c08-2dbf36ef6dbf, L2_cache_size=60MB)
# INFO 2025-08-23 00:41:46,606 2387159 sam3_model.py: 157: started new session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames), '2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14269 MiB used and 17220 MiB reserved (max over time: 14298 MiB used and 17220 MiB reserved); torch: 2.7.0+cu126 with CUDA arch ['sm_50', 'sm_60', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90'], GPU device: _CudaDeviceProperties(name='NVIDIA H200', major=9, minor=0, total_memory=143186MB, multi_processor_count=132, uuid=df9292d9-0c5f-e1b9-0d54-7b9678708823, L2_cache_size=60MB)
# frame loading (MP4 w/ GPU):  39%|███▉      | 106/270 [00:00<00:00, 226.98it/s]INFO 2025-08-23 00:41:46,660 2387157 sam3_model.py: 157: started new session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames), '2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14444 MiB used and 17226 MiB reserved (max over time: 14473 MiB used and 17226 MiB reserved); torch: 2.7.0+cu126 with CUDA arch ['sm_50', 'sm_60', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90'], GPU device: _CudaDeviceProperties(name='NVIDIA H200', major=9, minor=0, total_memory=143186MB, multi_processor_count=132, uuid=36e75de6-3d1c-81fa-3f50-e6680795ba4b, L2_cache_size=60MB)
# INFO 2025-08-23 00:41:46,663 2387160 sam3_model.py: 157: started new session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames), '2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14155 MiB used and 17108 MiB reserved (max over time: 14182 MiB used and 17108 MiB reserved); torch: 2.7.0+cu126 with CUDA arch ['sm_50', 'sm_60', 'sm_70', 'sm_75', 'sm_80', 'sm_86', 'sm_90'], GPU device: _CudaDeviceProperties(name='NVIDIA H200', major=9, minor=0, total_memory=143186MB, multi_processor_count=132, uuid=80d7f443-1c48-3ba3-f4c8-9e9c19b5d815, L2_cache_size=60MB)
# frame loading (MP4 w/ GPU): 100%|██████████| 270/270 [00:01<00:00, 212.62it/s]s]
# frame loading (MP4 w/ GPU): 100%|██████████| 270/270 [00:01<00:00, 186.75it/s]
# frame loading (MP4 w/ GPU): 100%|██████████| 270/270 [00:01<00:00, 186.17it/s]
# frame loading (MP4 w/ GPU): 100%|██████████| 270/270 [00:01<00:00, 178.92it/s]
# frame loading (MP4 w/ GPU): 100%|██████████| 270/270 [00:01<00:00, 178.85it/s]
# frame loading (MP4 w/ GPU): 100%|████████████| 270/270 [00:01<00:00, 178.96it/s]
# frame loading (MP4 w/ GPU): 100%|██████████| 270/270 [00:01<00:00, 176.23it/s]
# frame loading (MP4 w/ GPU): 100%|██████████| 270/270 [00:01<00:00, 173.38it/s]
# INFO 2025-08-23 00:59:39,276 2387160 sam3_model.py: 308: removed expired session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14150 MiB used and 17108 MiB reserved (max over time: 14182 MiB used and 17108 MiB reserved)
# INFO 2025-08-23 00:59:39,284 2387161 sam3_model.py: 308: removed expired session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14146 MiB used and 17118 MiB reserved (max over time: 14178 MiB used and 17118 MiB reserved)
# INFO 2025-08-23 00:59:39,319 2387156 sam3_model.py: 308: removed expired session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14439 MiB used and 17242 MiB reserved (max over time: 14471 MiB used and 17242 MiB reserved)
# INFO 2025-08-23 00:59:39,325 2387157 sam3_model.py: 308: removed expired session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14441 MiB used and 17226 MiB reserved (max over time: 14473 MiB used and 17226 MiB reserved)
# INFO 2025-08-23 00:59:40,318 2387155 sam3_model.py: 308: removed expired session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14439 MiB used and 17314 MiB reserved (max over time: 14471 MiB used and 17314 MiB reserved)
# INFO 2025-08-23 00:59:40,325 2387158 sam3_model.py: 308: removed expired session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14268 MiB used and 17224 MiB reserved (max over time: 14299 MiB used and 17224 MiB reserved)
# INFO 2025-08-23 00:59:40,393 2387159 sam3_model.py: 308: removed expired session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['2bf62b17-b089-45e6-8b0e-d052e6fd698d' (270 frames), 'f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 14267 MiB used and 17220 MiB reserved (max over time: 14298 MiB used and 17220 MiB reserved)
# INFO 2025-08-23 01:00:39,737 2387161 sam3_model.py: 308: removed expired session 2bf62b17-b089-45e6-8b0e-d052e6fd698d; live sessions: ['f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 11314 MiB used and 17118 MiB reserved (max over time: 14178 MiB used and 17118 MiB reserved)
# INFO 2025-08-23 01:00:39,740 2387160 sam3_model.py: 308: removed expired session 2bf62b17-b089-45e6-8b0e-d052e6fd698d; live sessions: ['f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 11314 MiB used and 17108 MiB reserved (max over time: 14182 MiB used and 17108 MiB reserved)
# INFO 2025-08-23 01:00:39,789 2387157 sam3_model.py: 308: removed expired session 2bf62b17-b089-45e6-8b0e-d052e6fd698d; live sessions: ['f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 11347 MiB used and 17226 MiB reserved (max over time: 14473 MiB used and 17226 MiB reserved)
# INFO 2025-08-23 01:00:39,790 2387156 sam3_model.py: 308: removed expired session 2bf62b17-b089-45e6-8b0e-d052e6fd698d; live sessions: ['f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 11348 MiB used and 17242 MiB reserved (max over time: 14471 MiB used and 17242 MiB reserved)
# INFO 2025-08-23 01:00:40,689 2387155 sam3_model.py: 308: removed expired session 2bf62b17-b089-45e6-8b0e-d052e6fd698d; live sessions: ['f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 11348 MiB used and 17314 MiB reserved (max over time: 14471 MiB used and 17314 MiB reserved)
# INFO 2025-08-23 01:00:40,713 2387158 sam3_model.py: 308: removed expired session 2bf62b17-b089-45e6-8b0e-d052e6fd698d; live sessions: ['f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 11348 MiB used and 17224 MiB reserved (max over time: 14299 MiB used and 17224 MiB reserved)
# INFO 2025-08-23 01:00:40,843 2387159 sam3_model.py: 308: removed expired session 2bf62b17-b089-45e6-8b0e-d052e6fd698d; live sessions: ['f948a2c7-533f-4e59-8abc-f11937b7a600' (270 frames), '2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 11347 MiB used and 17220 MiB reserved (max over time: 14298 MiB used and 17220 MiB reserved)
# INFO 2025-08-23 01:01:10,161 2387161 sam3_model.py: 308: removed expired session f948a2c7-533f-4e59-8abc-f11937b7a600; live sessions: ['2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 9744 MiB used and 17118 MiB reserved (max over time: 14178 MiB used and 17118 MiB reserved)
# INFO 2025-08-23 01:01:10,175 2387160 sam3_model.py: 308: removed expired session f948a2c7-533f-4e59-8abc-f11937b7a600; live sessions: ['2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 9744 MiB used and 17108 MiB reserved (max over time: 14182 MiB used and 17108 MiB reserved)
# INFO 2025-08-23 01:01:10,214 2387157 sam3_model.py: 308: removed expired session f948a2c7-533f-4e59-8abc-f11937b7a600; live sessions: ['2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 9777 MiB used and 17226 MiB reserved (max over time: 14473 MiB used and 17226 MiB reserved)
# INFO 2025-08-23 01:01:10,224 2387156 sam3_model.py: 308: removed expired session f948a2c7-533f-4e59-8abc-f11937b7a600; live sessions: ['2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 9777 MiB used and 17242 MiB reserved (max over time: 14471 MiB used and 17242 MiB reserved)
# INFO 2025-08-23 01:01:11,019 2387155 sam3_model.py: 308: removed expired session f948a2c7-533f-4e59-8abc-f11937b7a600; live sessions: ['2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 9777 MiB used and 17314 MiB reserved (max over time: 14471 MiB used and 17314 MiB reserved)
# INFO 2025-08-23 01:01:11,090 2387158 sam3_model.py: 308: removed expired session f948a2c7-533f-4e59-8abc-f11937b7a600; live sessions: ['2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 9777 MiB used and 17224 MiB reserved (max over time: 14299 MiB used and 17224 MiB reserved)
# INFO 2025-08-23 01:01:11,261 2387159 sam3_model.py: 308: removed expired session f948a2c7-533f-4e59-8abc-f11937b7a600; live sessions: ['2fc95f85-2422-45e6-a946-96fdeab386e7' (270 frames), '3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 9777 MiB used and 17220 MiB reserved (max over time: 14298 MiB used and 17220 MiB reserved)
# INFO 2025-08-23 01:01:40,580 2387161 sam3_model.py: 308: removed expired session 2fc95f85-2422-45e6-a946-96fdeab386e7; live sessions: ['3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 8173 MiB used and 17118 MiB reserved (max over time: 14178 MiB used and 17118 MiB reserved)
# INFO 2025-08-23 01:01:40,600 2387160 sam3_model.py: 308: removed expired session 2fc95f85-2422-45e6-a946-96fdeab386e7; live sessions: ['3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 8173 MiB used and 17108 MiB reserved (max over time: 14182 MiB used and 17108 MiB reserved)
# INFO 2025-08-23 01:01:40,643 2387157 sam3_model.py: 308: removed expired session 2fc95f85-2422-45e6-a946-96fdeab386e7; live sessions: ['3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 8206 MiB used and 17226 MiB reserved (max over time: 14473 MiB used and 17226 MiB reserved)
# INFO 2025-08-23 01:01:40,655 2387156 sam3_model.py: 308: removed expired session 2fc95f85-2422-45e6-a946-96fdeab386e7; live sessions: ['3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 8207 MiB used and 17242 MiB reserved (max over time: 14471 MiB used and 17242 MiB reserved)
# INFO 2025-08-23 01:01:41,349 2387155 sam3_model.py: 308: removed expired session 2fc95f85-2422-45e6-a946-96fdeab386e7; live sessions: ['3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 8207 MiB used and 17314 MiB reserved (max over time: 14471 MiB used and 17314 MiB reserved)
# INFO 2025-08-23 01:01:41,451 2387158 sam3_model.py: 308: removed expired session 2fc95f85-2422-45e6-a946-96fdeab386e7; live sessions: ['3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 8207 MiB used and 17224 MiB reserved (max over time: 14299 MiB used and 17224 MiB reserved)
# INFO 2025-08-23 01:01:41,666 2387159 sam3_model.py: 308: removed expired session 2fc95f85-2422-45e6-a946-96fdeab386e7; live sessions: ['3fbf56dd-1848-4845-856b-fb6adf47c80a' (270 frames)], GPU memory: 8206 MiB used and 17220 MiB reserved (max over time: 14298 MiB used and 17220 MiB reserved)
# INFO 2025-08-23 01:02:10,994 2387161 sam3_model.py: 308: removed expired session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: [], GPU memory: 6602 MiB used and 17118 MiB reserved (max over time: 14178 MiB used and 17118 MiB reserved)
# INFO 2025-08-23 01:02:11,028 2387160 sam3_model.py: 308: removed expired session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: [], GPU memory: 6602 MiB used and 17108 MiB reserved (max over time: 14182 MiB used and 17108 MiB reserved)
# INFO 2025-08-23 01:02:11,074 2387157 sam3_model.py: 308: removed expired session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: [], GPU memory: 6635 MiB used and 17226 MiB reserved (max over time: 14473 MiB used and 17226 MiB reserved)
# INFO 2025-08-23 01:02:11,078 2387156 sam3_model.py: 308: removed expired session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: [], GPU memory: 6636 MiB used and 17242 MiB reserved (max over time: 14471 MiB used and 17242 MiB reserved)
# INFO 2025-08-23 01:02:11,677 2387155 sam3_model.py: 308: removed expired session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: [], GPU memory: 6636 MiB used and 17314 MiB reserved (max over time: 14471 MiB used and 17314 MiB reserved)
# INFO 2025-08-23 01:02:11,797 2387158 sam3_model.py: 308: removed expired session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: [], GPU memory: 6636 MiB used and 17224 MiB reserved (max over time: 14299 MiB used and 17224 MiB reserved)
# INFO 2025-08-23 01:02:12,061 2387159 sam3_model.py: 308: removed expired session 3fbf56dd-1848-4845-856b-fb6adf47c80a; live sessions: [], GPU memory: 6635 MiB used and 17220 MiB reserved (max over time: 14298 MiB used and 17220 MiB reserved)

# %%
import torch
import torchcodec

print("PyTorch CUDA available:", torch.cuda.is_available())
print("TorchCodec version:", torchcodec.__version__)

# Try a simple decode call with GPU device (replace with your actual decode call)
try:
    # Example: decode with device cuda:0
    result = torchcodec.decode(video_path, device="cuda:0")
    print("TorchCodec GPU decode test: (run your decode call here)")
except Exception as e:
    print("TorchCodec GPU decode failed:", e)
# Out:
# PyTorch CUDA available: True
# TorchCodec version: 0.5+cu126
# TorchCodec GPU decode failed: module 'torchcodec' has no attribute 'decode'

# %% [markdown]
# ### Adding a text prompt on frame 0 and propagation throughout the video
#
# Note that the first call might be slower due to setting up buffers. **You can rerun all the cells below when measuring speed.**

# %%
# note: in case you already ran one text prompt and now want to switch to another text prompt
# it's required to reset the session first (otherwise the results would be wrong)
_ = model_wrapper.handle_request(
    request=dict(
        type="reset_session",
        session_id=session_id,
    )
)
# Out:
# INFO 2025-08-23 00:39:25,124 2386646 sam3_model.py: 254: clear all inputs across the video in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,125 2387157 sam3_model_multigpu.py: 154: worker rank=3 received request request['type']='reset_session'
# INFO 2025-08-23 00:39:25,125 2387161 sam3_model_multigpu.py: 154: worker rank=7 received request request['type']='reset_session'
# INFO 2025-08-23 00:39:25,125 2387157 sam3_model.py: 254: clear all inputs across the video in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,125 2387161 sam3_model.py: 254: clear all inputs across the video in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,125 2387160 sam3_model_multigpu.py: 154: worker rank=6 received request request['type']='reset_session'
# INFO 2025-08-23 00:39:25,125 2387160 sam3_model.py: 254: clear all inputs across the video in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,126 2387159 sam3_model_multigpu.py: 154: worker rank=5 received request request['type']='reset_session'
# INFO 2025-08-23 00:39:25,126 2387159 sam3_model.py: 254: clear all inputs across the video in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,126 2387155 sam3_model_multigpu.py: 154: worker rank=1 received request request['type']='reset_session'
# INFO 2025-08-23 00:39:25,126 2387155 sam3_model.py: 254: clear all inputs across the video in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,128 2387156 sam3_model_multigpu.py: 154: worker rank=2 received request request['type']='reset_session'
# INFO 2025-08-23 00:39:25,128 2387156 sam3_model.py: 254: clear all inputs across the video in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,128 2387158 sam3_model_multigpu.py: 154: worker rank=4 received request request['type']='reset_session'
# INFO 2025-08-23 00:39:25,128 2387158 sam3_model.py: 254: clear all inputs across the video in session 360651fa-199f-44a7-87f7-072da9fab405

# %%
frame_idx = 0  # add a text prompt on frame 0
response = model_wrapper.handle_request(
    request=dict(
        type="add_prompt",
        session_id=session_id,
        frame_index=frame_idx,
        text=prompt_text_str,
    )
)
out = response["outputs"]
# Out:
# INFO 2025-08-23 00:39:25,567 2386646 sam3_model.py: 177: add prompt on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405: text='person', points=None, point_labels=None, clear_old_points=None, bounding_boxes=None, bounding_box_labels=None, clear_old_boxes=None
# INFO 2025-08-23 00:39:25,568 2387155 sam3_model_multigpu.py: 154: worker rank=1 received request request['type']='add_prompt'
# INFO 2025-08-23 00:39:25,568 2387155 sam3_model.py: 177: add prompt on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405: text='person', points=None, point_labels=None, clear_old_points=None, bounding_boxes=None, bounding_box_labels=None, clear_old_boxes=None
# INFO 2025-08-23 00:39:25,568 2387155 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# INFO 2025-08-23 00:39:25,568 2387158 sam3_model_multigpu.py: 154: worker rank=4 received request request['type']='add_prompt'
# INFO 2025-08-23 00:39:25,568 2387158 sam3_model.py: 177: add prompt on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405: text='person', points=None, point_labels=None, clear_old_points=None, bounding_boxes=None, bounding_box_labels=None, clear_old_boxes=None
# INFO 2025-08-23 00:39:25,568 2387161 sam3_model_multigpu.py: 154: worker rank=7 received request request['type']='add_prompt'
# INFO 2025-08-23 00:39:25,568 2387158 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# INFO 2025-08-23 00:39:25,568 2387161 sam3_model.py: 177: add prompt on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405: text='person', points=None, point_labels=None, clear_oldINFO 2025-08-23 00:39:25,571 2386646 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# _points=None, bounding_boxes=None, bounding_box_labels=None, clear_old_boxes=None
# INFO 2025-08-23 00:39:25,568 2387161 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# INFO 2025-08-23 00:39:25,568 2387159 sam3_model_multigpu.py: 154: worker rank=5 received request request['type']='add_prompt'
# INFO 2025-08-23 00:39:25,569 2387159 sam3_model.py: 177: add prompt on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405: text='person', points=None, point_labels=None, clear_old_points=None, bounding_boxes=None, bounding_box_labels=None, clear_old_boxes=None
# INFO 2025-08-23 00:39:25,569 2387159 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# INFO 2025-08-23 00:39:25,569 2387157 sam3_model_multigpu.py: 154: worker rank=3 received request request['type']='add_prompt'
# INFO 2025-08-23 00:39:25,569 2387157 sam3_model.py: 177: add prompt on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405: text='person', points=None, point_labels=None, clear_old_points=None, bounding_boxes=None, bounding_box_labels=None, clear_old_boxes=None
# INFO 2025-08-23 00:39:25,569 2387157 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# INFO 2025-08-23 00:39:25,570 2387156 sam3_model_multigpu.py: 154: worker rank=2 received request request['type']='add_prompt'
# INFO 2025-08-23 00:39:25,570 2387156 sam3_model.py: 177: add prompt on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405: text='person', points=None, point_labels=None, clear_old_points=None, bounding_boxes=None, bounding_box_labels=None, clear_old_boxes=None
# INFO 2025-08-23 00:39:25,570 2387156 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# INFO 2025-08-23 00:39:25,570 2387160 sam3_model_multigpu.py: 154: worker rank=6 received request request['type']='add_prompt'
# INFO 2025-08-23 00:39:25,570 2387160 sam3_model.py: 177: add prompt on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405: text='person', points=None, point_labels=None, clear_old_points=None, bounding_boxes=None, bounding_box_labels=None, clear_old_boxes=None
# INFO 2025-08-23 00:39:25,570 2387160 sam3_demo_dense_tracking_multigpu.py: 372: Running add_prompt on frame 0
# /checkpoint/sam3/ronghanghu/anaconda3/envs/onevision_sam3/lib/python3.10/site-packages/torch/nn/functional.py:5015: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# INFO 2025-08-23 00:39:25,764 2387158 sam3_model.py: 198: got 0 objects on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,764 2387161 sam3_model.py: 198: got 0 objects on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,764 2387159 sam3_model.py: 198: got 0 objects on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,764 2387160 sam3_model.py: 198: got 0 objects on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,860 2387155 sam3_model.py: 198: got 0 objects on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,860 2387156 sam3_model.py: 198: got 0 objects on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,860 2387157 sam3_model.py: 198: got 0 objects on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405
# INFO 2025-08-23 00:39:25,868 2386646 sam3_model.py: 198: got 4 objects on frame 0 in session 360651fa-199f-44a7-87f7-072da9fab405

# %%
import cv2
import os

video_path = new_video_frames  # path to your .mp4 file
frames_dir = "/tmp/extracted_frames"  # temp directory to store frames
os.makedirs(frames_dir, exist_ok=True)

cap = cv2.VideoCapture(video_path)
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
image_files_from_video = []

for i in range(frame_count):
    ret, frame = cap.read()
    if not ret:
        break
    frame_path = os.path.join(frames_dir, f"{i}.jpg")
    cv2.imwrite(frame_path, frame)
    image_files_from_video.append(frame_path)

cap.release()

# Now sort as before
try:
    image_files_from_video.sort(key=lambda p: int(os.path.splitext(os.path.basename(p))[0]))
except ValueError:
    print(
        f'frame names are not in "<frame_index>.jpg" format: {image_files[:5]=}, '
        f"falling back to lexicographic sort."
    )
    image_files_from_video.sort()

# %%
from PIL import Image
import matplotlib.pyplot as plt

img_path = "/tmp/extracted_frames/20.jpg"
img = Image.open(img_path)

plt.imshow(img)
plt.axis('off')  # Hide axes
plt.show()

# %%
plt.close("all")
frame_idx = 0
visualize_formatted_frame_output(
    frame_idx,
    image_files_from_video,
    outputs_list=[prepare_masks_for_visualization({frame_idx: out})], 
    titles=["SAM 3 Dense Tracking outputs"], 
    figsize=(6, 4),
)

# %%
# we will just propagate from frame 0 to the end of the video
outputs_per_frame = {}
for response in model_wrapper.handle_stream_request(
    request=dict(
        type="propagate_in_video",
        session_id=session_id,
    )
):
    outputs_per_frame[response["frame_index"]] = response["outputs"]
outputs_per_frame = prepare_masks_for_visualization(outputs_per_frame)
# Out:
# INFO 2025-08-23 00:39:30,395 2386646 sam3_model.py: 212: propagate in video in session 360651fa-199f-44a7-87f7-072da9fab405: propagation_direction='both', start_frame_idx=None, max_frame_num_to_track=None
# INFO 2025-08-23 00:39:30,396 2387158 sam3_model_multigpu.py: 154: worker rank=4 received request request['type']='propagate_in_video'
# INFO 2025-08-23 00:39:30,396 2387157 sam3_model_multigpu.py: 154: worker rank=3 received request request['type']='propagate_in_video'
# INFO 2025-08-23 00:39:30,396 2387158 sam3_model.py: 212: propagate in video in session 360651fa-199f-44a7-87f7-072da9fab405: propagation_direction='both', start_frame_idx=None, max_frame_num_to_track=None
# INFO 2025-08-23 00:39:30,396 2387157 sam3_model.py: 212: propagate in video in session 360651fa-199f-44a7-87f7-072da9fab405: propagation_direction='both', start_frame_idx=None, max_frame_num_to_track=None
# INFO 2025-08-23 00:39:30,397 2387159 sam3_model_multigpu.py: 154: worker rank=5 received request request['type']='propagate_in_video'
# INFO 2025-08-23 00:39:30,397 2387159 sam3_model.py: 212: propagate in video in session 360651fa-199f-44a7-87f7-072da9fab405: propagation_direction='both', start_frame_idx=None, max_frame_num_to_track=None
# INFO 2025-08-23 00:39:30,397 2387155 sam3_model_multigpu.py: 154: worker rank=1 received request request['type']='propagate_in_video'
# INFO 2025-08-23 00:39:30,397 2387155 sam3_model.py: 212: propagate in video in session 360651fa-199f-44a7-87f7-072da9fab405: propagation_direction='both', start_frame_idx=None, max_frame_num_to_track=None
# INFO 2025-08-23 00:39:30,397 2387156 sam3_model_multigpu.py: 154: worker rank=2 received request request['type']='propagate_in_video'
# INFO 2025-08-23 00:39:30,397 2387156 sam3_model.py: 212: propagate in video in session 360651fa-199f-44a7-87f7-072da9fab405: propagation_direction='both', start_frame_idx=None, max_frame_num_to_track=None
# INFO 2025-08-23 00:39:30,398 2387161 sam3_model_multigpu.py: 154: worker rank=7 received request request['type']='propagate_in_video'
# INFO 2025-08-23 00:39:30,398 2387161 sam3_model.py: 212: propagate in video in session 360651fa-199f-44a7-87f7-072da9fab405: propagation_direction='both', start_frame_idx=None, max_frame_num_to_track=None
# INFO 2025-08-23 00:39:30,400 2387160 sam3_model_multigpu.py: 154: worker rank=6 received request request['type']='propagate_in_video'
# INFO 2025-08-23 00:39:30,400 2387160 sam3_model.py: 212: propagate in video in session 360651fa-199f-44a7-87f7-072da9fab405: propagation_direction='both', start_frame_idx=None, max_frame_num_to_track=None
# propagate_in_video:  98%|████████████████████▌| 265/270 [00:09<00:00, 36.37it/s]INFO 2025-08-23 00:39:40,314 2387156 sam3_model.py: 248: propagation ended in session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames)], GPU memory: 8156 MiB used and 10962 MiB reserved (max over time: 10009 MiB used and 10962 MiB reserved)
# INFO 2025-08-23 00:39:40,314 2387159 sam3_model.py: 248: propagation ended in session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames)], GPU memory: 7984 MiB used and 10940 MiB reserved (max over time: 9835 MiB used and 10940 MiB reserved)
# INFO 2025-08-23 00:39:40,314 2387155 sam3_model.py: 248: propagation ended in session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames)], GPU memory: 8156 MiB used and 11034 MiB reserved (max over time: 10007 MiB used and 11034 MiB reserved)
# INFO 2025-08-23 00:39:40,314 2387160 sam3_model.py: 248: propagation ended in session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames)], GPU memory: 7867 MiB used and 10828 MiB reserved (max over time: 9628 MiB used and 10828 MiB reserved)
# INFO 2025-08-23 00:39:40,314 2387158 sam3_model.py: 248: propagation ended in session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames)], GPU memory: 7985 MiB used and 10944 MiB reserved (max over time: 9836 MiB used and 10944 MiB reserved)
# INFO 2025-08-23 00:39:40,314 2387157 sam3_model.py: 248: propagation ended in session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames)], GPU memory: 8158 MiB used and 10946 MiB reserved (max over time: 10007 MiB used and 10946 MiB reserved)
# INFO 2025-08-23 00:39:40,315 2387161 sam3_model.py: 248: propagation ended in session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames)], GPU memory: 7864 MiB used and 10838 MiB reserved (max over time: 9627 MiB used and 10838 MiB reserved)
# propagate_in_video: 100%|█████████████████████| 270/270 [00:09<00:00, 27.19it/s]
# propagate_in_video: 0it [00:00, ?it/s]
# INFO 2025-08-23 00:39:40,334 2386646 sam3_model.py: 248: propagation ended in session 360651fa-199f-44a7-87f7-072da9fab405; live sessions: ['360651fa-199f-44a7-87f7-072da9fab405' (270 frames)], GPU memory: 8157 MiB used and 10946 MiB reserved (max over time: 10088 MiB used and 10946 MiB reserved)

# %%
vis_frame_stride = 60
plt.close("all")
for frame_idx in range(0, len(outputs_per_frame), vis_frame_stride):
    visualize_formatted_frame_output(
        frame_idx, 
        image_files_from_video, 
        outputs_list=[outputs_per_frame], 
        titles=["SAM 3 Dense Tracking outputs"], 
        figsize=(6, 4),
    )
